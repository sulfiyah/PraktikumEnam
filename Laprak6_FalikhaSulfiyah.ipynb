# %%
x = int(input("Masukkan angka :"))
s = x - 1
for i in range(0, x):
  for j in range(0, s):
    print(' ', end = '')
  s -= 1
  for j in range(0, i +1):
    print('* ', end ='')

  print('')
# Out:
# Masukkan angka :10
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *

# %%
x = (int(input("masukkan angka:")))
for i in range (x):
  print(' ' * ( x - i), end = '')
  k = 1
  for j in range (i + 1):
    print(k, end = ' ')
    k = k * (i-j) // (j+1)
  print()
# Out:
# masukkan angka:4
#     1
#    1 1
#   1 2 1
#  1 3 3 1

# %%
n = int(input("Masukkan nilai:"))
a = 1
n = n - 1
jumlah = 0

for i in range (n + 1):
  print (a, end = ' ')
  jumlah += a

  a = a * (n - i) // (i + 1)
print(f"\nHasil penjumlahan angka di baris ke", n+1, "adalah", jumlah)
# Out:
# Masukkan nilai:7
# 1 6 15 20 15 6 1
# Hasil penjumlahan angka di baris ke 7 adalah 64
